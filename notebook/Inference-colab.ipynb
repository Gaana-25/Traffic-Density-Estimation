# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\91901\Desktop\yolo-v4-tf.keras-master\yolo-v4-tf.keras-master\notebook\Inference-colab.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91901/Desktop/yolo-v4-tf.keras-master/yolo-v4-tf.keras-master/notebook/Inference-colab.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell:/c%3A/Users/91901/Desktop/yolo-v4-tf.keras-master/yolo-v4-tf.keras-master/notebook/Inference-colab.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# download yolo v4 weights from GoogleDrive
# !gdown --id 1cewMfusmPjYWbrnuJRuKhPMwRe_b9PaT
# Out:
# 'gdown' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# update the yolov4 folder path of your own
import sys
FOLDER_PATH = 'YOUR PATH'
sys.path.append(FOLDER_PATH)

# %%
import cv2
import numpy as np
import os
from models import Yolov4
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\91901\Desktop\yolo-v4-tf.keras-master\yolo-v4-tf.keras-master\notebook\Inference-colab.ipynb Cell 4 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/91901/Desktop/yolo-v4-tf.keras-master/yolo-v4-tf.keras-master/notebook/Inference-colab.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/91901/Desktop/yolo-v4-tf.keras-master/yolo-v4-tf.keras-master/notebook/Inference-colab.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> import os
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91901/Desktop/yolo-v4-tf.keras-master/yolo-v4-tf.keras-master/notebook/Inference-colab.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> from models import Yolov4
#
# ModuleNotFoundError: No module named 'models'

# %%
# build yolo model
model = Yolov4(class_name_path = os.path.join(FOLDER_PATH, 'class_names', 'coco_classes.txt'),
               weight_path='yolov4.weights')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\91901\Desktop\yolo-v4-tf.keras-master\yolo-v4-tf.keras-master\notebook\Inference-colab.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/91901/Desktop/yolo-v4-tf.keras-master/yolo-v4-tf.keras-master/notebook/Inference-colab.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # build yolo model
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91901/Desktop/yolo-v4-tf.keras-master/yolo-v4-tf.keras-master/notebook/Inference-colab.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> model = Yolov4(class_name_path = os.path.join(FOLDER_PATH, 'class_names', 'coco_classes.txt'),
#       <a href='vscode-notebook-cell:/c%3A/Users/91901/Desktop/yolo-v4-tf.keras-master/yolo-v4-tf.keras-master/notebook/Inference-colab.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>                weight_path='yolov4.weights')
#
# NameError: name 'Yolov4' is not defined

# %%
model.predict(os.path.join(FOLDER_PATH, 'img', 'test3.jpg'), random_color=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\91901\Desktop\yolo-v4-tf.keras-master\yolo-v4-tf.keras-master\notebook\Inference-colab.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91901/Desktop/yolo-v4-tf.keras-master/yolo-v4-tf.keras-master/notebook/Inference-colab.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> model.predict(os.path.join(FOLDER_PATH, 'img', 'test3.jpg'), random_color=True)
#
# NameError: name 'model' is not defined
